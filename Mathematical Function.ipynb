# %%
import numpy as np

# %%
arr = np.array ([3,5,2,33,2,1,10,1])

# %%
np.mean(arr)
# Out:
# np.float64(7.125)

# %%
np.min(arr)
# Out:
# np.int64(1)

# %%
np.max(arr)
# Out:
# np.int64(33)

# %%
np.std(arr)
# Out:
# np.float64(10.16658128379447)

# %%
np.var(arr)
# Out:
# np.float64(103.359375)

# %%
np.sum(arr)
# Out:
# np.int64(57)

# %%
np.prod(arr)
# Out:
# np.int64(19800)

# %%
np.median(arr)
# Out:
# np.float64(2.5)

# %%
np.percentile(arr, 50)  # For the 50th percentile (median)
# Out:
# np.float64(2.5)

# %%
np.argmin(arr)
# Out:
# np.int64(5)

# %%
np.argmax(arr)
# Out:
# np.int64(3)

# %%
np.unique(arr)
# Out:
# array([ 1,  2,  3,  5, 10, 33])

# %%
np.diff(arr)
# Out:
# array([  2,  -3,  31, -31,  -1,   9,  -9])

# %%
np.cumsum(arr)
# Out:
# array([ 3,  8, 10, 43, 45, 46, 56, 57])
